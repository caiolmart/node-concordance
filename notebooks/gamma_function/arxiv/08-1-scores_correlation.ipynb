# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os

while 'notebooks' in os.getcwd():
    os.chdir('..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import roc_auc_score

from src.data.gamma.structural_arxiv import load_dataset, get_train_val_test_edges, prepare_adjencency, get_edge_index_from_adjencency

# %%
dataset_name = 'ogbn-arxiv'
folder = f'data/scored_omega/{dataset_name}'

# %%
dataset = load_dataset()

# %%
data, edges_train, edges_val, edges_test = get_train_val_test_edges(
    dataset, device='cpu'
)

# %%
os.listdir(folder)
# Out:
# ['positional_node2vec.csv',
#  'positional_graph_sage.csv',
#  'structural_mlp.csv',
#  'structural_omega_gcn_cossim.csv',
#  'structural_omega_graph_sage_cossim.csv',
#  'structural_omega_gat_cossim.csv']

# %%
model_parameters = [
    {
        'model_name': "$\Omega_{s}^{MLP}$",
        'file': 'structural_mlp.csv'
    },
    {
        'model_name': "$\Omega_{s}^{GraphSage}$",
        'file': 'structural_omega_graph_sage_cossim.csv'
    },
    {
        'model_name': "$\Omega_{s}^{GCN}$",
        'file': 'structural_omega_gcn_cossim.csv'
    },
    {
        'model_name': "$\Omega_{s}^{GAT}$",
        'file': 'structural_omega_gat_cossim.csv'
    },
    {
        'model_name': "$\Omega_{p}^{GraphSage}$",
        'file': 'positional_graph_sage.csv'
    },
    {
        'model_name': "$\Omega_{p}^{Node2Vec}$",
        'file': 'positional_node2vec.csv'
    }
]

# %%
file = model_parameters[0]['file']
scores = pd.read_csv(f'{folder}/{file}').set_index(['source', 'target'])['omega_pred']
scores
# Out:
# source  target
# 104447  13091     0.586956
# 15858   47283     0.641920
# 107156  69161     0.352049
#         136440    0.341153
#         107366    0.297747
#                     ...
# 45118   79124     0.886106
#         147994    0.742534
#         162473    0.756534
#         162537    0.708751
#         72717     0.539122
# Name: omega_pred, Length: 1166243, dtype: float64

# %%
edges_test[:, :5]
# Out:
# tensor([[105794,  75620, 138895, 133642, 144254],
#         [142957,  59683,  59683, 115102,  59326]])

# %%
test_scores = scores[edges_test.numpy().T.tolist()]
test_scores.head()
# Out:
# source  target
# 105794  142957    0.565479
# 75620   59683     0.585126
# 138895  59683     0.529595
# 133642  115102    0.488394
# 144254  59326     0.674076
# Name: omega_pred, dtype: float64

# %%
series_list = []
for model_dict in model_parameters:
    model_name = model_dict['model_name']
    file = model_dict['file']
    preds = (
        pd.read_csv(f'{folder}/{file}')
        .set_index(['source', 'target'])['omega_pred']
        .rename(model_name)
    )
    test_preds = preds[edges_test.numpy().T.tolist()]
    series_list.append(test_preds)

test_preds = pd.DataFrame(series_list).T
test_preds.head()
# Out:
#                $\Omega_{s}^{MLP}$  $\Omega_{s}^{GraphSage}$  \
# source target
# 105794 142957            0.565479                  0.889694
# 75620  59683             0.585126                  0.735009
# 138895 59683             0.529595                  0.834004
# 133642 115102            0.488394                  0.585439
# 144254 59326             0.674076                  0.703309
#
#                $\Omega_{s}^{GCN}$  $\Omega_{s}^{GAT}$  \
# source target
# 105794 142957            0.901015            0.911929
# 75620  59683             0.915940            0.902966
# 138895 59683             0.909675            0.921977
# 133642 115102            0.691818            0.785906
# 144254 59326             0.892085            0.836083
#
#                $\Omega_{p}^{GraphSage}$  $\Omega_{p}^{Node2Vec}$
# source target
# 105794 142957                  0.700079                 0.690346
# 75620  59683                   0.662867                 0.674190
# 138895 59683                   0.618921                 0.641028
# 133642 115102                  0.711059                 0.669982
# 144254 59326                   0.738485                 0.708185

# %%
test_preds.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_bf6d3_row0_col0, #T_bf6d3_row1_col1, #T_bf6d3_row2_col2, #T_bf6d3_row3_col3, #T_bf6d3_row4_col4, #T_bf6d3_row5_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_bf6d3_row0_col1, #T_bf6d3_row5_col2 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_bf6d3_row0_col2 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_bf6d3_row0_col3 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_bf6d3_row0_col4, #T_bf6d3_row0_col5, #T_bf6d3_row4_col0, #T_bf6d3_row4_col1, #T_bf6d3_row4_col2, #T_bf6d3_row4_col3, #T_bf6d3_row5_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_bf6d3_row1_col0 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_bf6d3_row1_col2 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_bf6d3_row1_col3 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_bf6d3_row1_col4, #T_bf6d3_row5_col3 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_bf6d3_row1_col5 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_bf6d3_row2_col0 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_bf6d3_row2_col1 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_bf6d3_row2_col3 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_bf6d3_row2_col4 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_bf6d3_row2_col5 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_bf6d3_row3_col0 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_bf6d3_row3_col1 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_bf6d3_row3_col2 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_bf6d3_row3_col4 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_bf6d3_row3_col5 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_bf6d3_row4_col5, #T_bf6d3_row5_col4 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_bf6d3_row5_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# </style>
# <table id="T_bf6d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf6d3_level0_col0" class="col_heading level0 col0" >$\Omega_{s}^{MLP}$</th>
#       <th id="T_bf6d3_level0_col1" class="col_heading level0 col1" >$\Omega_{s}^{GraphSage}$</th>
#       <th id="T_bf6d3_level0_col2" class="col_heading level0 col2" >$\Omega_{s}^{GCN}$</th>
#       <th id="T_bf6d3_level0_col3" class="col_heading level0 col3" >$\Omega_{s}^{GAT}$</th>
#       <th id="T_bf6d3_level0_col4" class="col_heading level0 col4" >$\Omega_{p}^{GraphSage}$</th>
#       <th id="T_bf6d3_level0_col5" class="col_heading level0 col5" >$\Omega_{p}^{Node2Vec}$</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf6d3_level0_row0" class="row_heading level0 row0" >$\Omega_{s}^{MLP}$</th>
#       <td id="T_bf6d3_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_bf6d3_row0_col1" class="data row0 col1" >0.400405</td>
#       <td id="T_bf6d3_row0_col2" class="data row0 col2" >0.382868</td>
#       <td id="T_bf6d3_row0_col3" class="data row0 col3" >0.362428</td>
#       <td id="T_bf6d3_row0_col4" class="data row0 col4" >0.171635</td>
#       <td id="T_bf6d3_row0_col5" class="data row0 col5" >0.171017</td>
#     </tr>
#     <tr>
#       <th id="T_bf6d3_level0_row1" class="row_heading level0 row1" >$\Omega_{s}^{GraphSage}$</th>
#       <td id="T_bf6d3_row1_col0" class="data row1 col0" >0.400405</td>
#       <td id="T_bf6d3_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_bf6d3_row1_col2" class="data row1 col2" >0.772815</td>
#       <td id="T_bf6d3_row1_col3" class="data row1 col3" >0.759573</td>
#       <td id="T_bf6d3_row1_col4" class="data row1 col4" >0.282441</td>
#       <td id="T_bf6d3_row1_col5" class="data row1 col5" >0.376843</td>
#     </tr>
#     <tr>
#       <th id="T_bf6d3_level0_row2" class="row_heading level0 row2" >$\Omega_{s}^{GCN}$</th>
#       <td id="T_bf6d3_row2_col0" class="data row2 col0" >0.382868</td>
#       <td id="T_bf6d3_row2_col1" class="data row2 col1" >0.772815</td>
#       <td id="T_bf6d3_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_bf6d3_row2_col3" class="data row2 col3" >0.815919</td>
#       <td id="T_bf6d3_row2_col4" class="data row2 col4" >0.306356</td>
#       <td id="T_bf6d3_row2_col5" class="data row2 col5" >0.422731</td>
#     </tr>
#     <tr>
#       <th id="T_bf6d3_level0_row3" class="row_heading level0 row3" >$\Omega_{s}^{GAT}$</th>
#       <td id="T_bf6d3_row3_col0" class="data row3 col0" >0.362428</td>
#       <td id="T_bf6d3_row3_col1" class="data row3 col1" >0.759573</td>
#       <td id="T_bf6d3_row3_col2" class="data row3 col2" >0.815919</td>
#       <td id="T_bf6d3_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_bf6d3_row3_col4" class="data row3 col4" >0.310992</td>
#       <td id="T_bf6d3_row3_col5" class="data row3 col5" >0.403329</td>
#     </tr>
#     <tr>
#       <th id="T_bf6d3_level0_row4" class="row_heading level0 row4" >$\Omega_{p}^{GraphSage}$</th>
#       <td id="T_bf6d3_row4_col0" class="data row4 col0" >0.171635</td>
#       <td id="T_bf6d3_row4_col1" class="data row4 col1" >0.282441</td>
#       <td id="T_bf6d3_row4_col2" class="data row4 col2" >0.306356</td>
#       <td id="T_bf6d3_row4_col3" class="data row4 col3" >0.310992</td>
#       <td id="T_bf6d3_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_bf6d3_row4_col5" class="data row4 col5" >0.374156</td>
#     </tr>
#     <tr>
#       <th id="T_bf6d3_level0_row5" class="row_heading level0 row5" >$\Omega_{p}^{Node2Vec}$</th>
#       <td id="T_bf6d3_row5_col0" class="data row5 col0" >0.171017</td>
#       <td id="T_bf6d3_row5_col1" class="data row5 col1" >0.376843</td>
#       <td id="T_bf6d3_row5_col2" class="data row5 col2" >0.422731</td>
#       <td id="T_bf6d3_row5_col3" class="data row5 col3" >0.403329</td>
#       <td id="T_bf6d3_row5_col4" class="data row5 col4" >0.374156</td>
#       <td id="T_bf6d3_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(1, 1, figsize=(6.5, 6))

fig.suptitle('ogbn-arxiv - Correlations Between Model Predictions')

sns.heatmap(
    test_preds.corr(),
    cmap='Blues',
    annot=True,
    cbar=False,
    fmt='.3f',
    ax=ax
)

ax.tick_params(axis='y', rotation=0)

plt.savefig('reports/images/ogbn-arxiv/correlation_matrix_test.pdf')

# %%
test_preds['theta'] = (data.y[edges_test[0]] == data.y[edges_test[1]] * 1).numpy().squeeze()

# %%
auc_dict = {}
for p in np.linspace(0, 1, 51):
    score = test_preds[r'$\Omega_{p}^{GraphSage}$'].mul(p).add(
        test_preds[r'$\Omega_{s}^{GCN}$'].mul(1-p))
    auc = roc_auc_score(test_preds['theta'], score)
    auc_dict[p] = auc

# %%
pd.Series(auc_dict).idxmax()
# Out:
# 0.1

# %%
(
    pd.Series(auc_dict)
    .rename('ROC-AUC')
    .rename_axis('p')
    .to_frame()
    .query('p < 0.5')
    .reset_index()
    .plot(kind='scatter', x='p', y='ROC-AUC', figsize=(6, 4))
)


plt.title('ROC-AUC of ensemble: $p\Omega_{p}^{GraphSage} + (1-p)\Omega_{s}^{GCN}$')
# Out:
# Text(0.5, 1.0, 'ROC-AUC of ensemble: $p\\Omega_{p}^{GraphSage} + (1-p)\\Omega_{s}^{GCN}$')

# %%
auc_df = (
    pd.Series(auc_dict)
    .rename('ROC-AUC')
    .rename_axis('p')
    .to_frame()
    .query('p < 0.5')
    .reset_index()
    .query('p < 0.5')
)

# %%
auc_df['ROC-AUC'].max()
# Out:
# 0.8268410792472933

# %%
auc_df['ROC-AUC'].iloc[0]
# Out:
# 0.8263290641863809

# %%
(
    pd.Series(auc_dict)
    .rename('ROC-AUC')
    .rename_axis('p')
    .to_frame()
)
# Out:
#        ROC-AUC
# p
# 0.00  0.826329
# 0.02  0.826574
# 0.04  0.826710
# 0.06  0.826789
# 0.08  0.826829
# 0.10  0.826841
# 0.12  0.826829
# 0.14  0.826797
# 0.16  0.826747
# 0.18  0.826680
# 0.20  0.826597
# 0.22  0.826499
# 0.24  0.826386
# 0.26  0.826258
# 0.28  0.826114
# 0.30  0.825954
# 0.32  0.825779
# 0.34  0.825587
# 0.36  0.825378
# 0.38  0.825150
# 0.40  0.824902
# 0.42  0.824634
# 0.44  0.824343
# 0.46  0.824026
# 0.48  0.823683
# 0.50  0.823309
# 0.52  0.822902
# 0.54  0.822458
# 0.56  0.821973
# 0.58  0.821440
# 0.60  0.820854
# 0.62  0.820206
# 0.64  0.819488
# 0.66  0.818688
# 0.68  0.817793
# 0.70  0.816791
# 0.72  0.815663
# 0.74  0.814394
# 0.76  0.812964
# 0.78  0.811352
# 0.80  0.809512
# 0.82  0.807395
# 0.84  0.804931
# 0.86  0.802013
# 0.88  0.798509
# 0.90  0.794212
# 0.92  0.788733
# 0.94  0.781373
# 0.96  0.770564
# 0.98  0.751733
# 1.00  0.683111

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))

ax1.set_title('ogbn-arxiv - Correlations Between Model Predictions')

sns.heatmap(
    test_preds.drop(columns=['theta']).corr(),
    cmap='Blues',
    annot=True,
    cbar=False,
    fmt='.3f',
    ax=ax1
)

ax1.tick_params(axis='y', rotation=0)


ax2.scatter(auc_df['p'], auc_df['ROC-AUC'])
ax2.set_ylabel('ROC-AUC')
ax2.set_xlabel('$p$')

ax2.set_title('ogbn-arxiv - ROC-AUC of Ensemble: $p \cdot \Omega_{p}^{GCN} + (1-p)\cdot\Omega_{s}^{GCN}$')
plt.savefig('reports/images/ogbn-arxiv/correlation_matrix_auc_ensemble.pdf')
