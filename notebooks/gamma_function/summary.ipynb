# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

while 'notebooks' in os.getcwd():
    os.chdir('..')

import pandas as pd
import numpy as np
from sklearn.model_selection import ParameterGrid

from src.train.structural_omega.graph_sage import StructuralOmegaGraphSageCosSim
from src.train.structural_omega.gcn import StructuralOmegaGCNCosSim
from src.train.structural_omega.mlp import StructuralOmegaMLP
from src.train.structural_omega.gat import StructuralOmegaGATCosSim
from src.train.positional_omega.graph_sage import PositionalOmegaGraphSageCosSim
from src.train.positional_omega.node2vec import PositionalOmegaNode2Vec

# %%
model_parameters = [
    {
        'model': StructuralOmegaMLP,
        'model_name': "$\Omega_{s}MLP$",
        'parameter_range':{
            'n_layers': list(range(1, 6))
        }
    },
    {
        'model': StructuralOmegaGraphSageCosSim,
        'model_name': "$\Omega_{s}GraphSage$",
        'parameter_range':{
            'n_layers_graph_sage': list(range(1, 4))
        }
    },
    {
        'model': StructuralOmegaGCNCosSim,
        'model_name': "$\Omega_{s}GCN$",
        'parameter_range':{
            'n_layers_gcn': list(range(1, 4))
        }
    },
    {
        'model': StructuralOmegaGATCosSim,
        'model_name': "$\Omega_{s}GAT$",
        'parameter_range':{
            'n_layers_gat': list(range(1, 4))
        }
    },
    {
        'model': PositionalOmegaGraphSageCosSim,
        'model_name': "$\Omega_{p}GraphSage$",
        'parameter_range':{
            'n_layers': list(range(1, 4))
        }
    },
    {
        'model': PositionalOmegaNode2Vec,
        'model_name': "$\Omega_{p}Node2Vec$",
        'parameter_range':{
            'p': np.logspace(-1, 1, 5).round(2).tolist(),
            'q': np.logspace(-1, 1, 5).round(2).tolist()
        }
    }
]

# %%
model_series_list = []
for dataset in ['ogbn-arxiv', 'cora', 'pubmed']:
    for model_dict in model_parameters:
        model = model_dict['model']
        model_name = model_dict['model_name']
        for params in ParameterGrid(model_dict['parameter_range']):
            metrics = model.read_metrics(dataset, **params)
            aucs_list = []
            for run in metrics['run'].unique():
                sub_df = metrics.query(f'run == {run}')
                idxmax = sub_df['auc_val'].idxmax()
                aucs = sub_df.loc[idxmax, ['auc_train', 'auc_val', 'auc_test']]
                aucs_list.append(aucs.rename(run))

            aucs_df = pd.concat(aucs_list, axis=1).rename_axis(columns='run').T
            aucs_mean = aucs_df.mean()
            aucs_std = aucs_df.std()

            model_series_list.append(pd.Series({
                'dataset': dataset,
                'model_name': model_name,
                'params': params,
                'mean_auc_train': aucs_mean['auc_train'],
                'std_auc_train': aucs_std['auc_train'],
                'mean_auc_val': aucs_mean['auc_val'],
                'std_auc_val': aucs_std['auc_val'],
                'mean_auc_test': aucs_mean['auc_test'],
                'std_auc_test': aucs_std['auc_test'],
            }))

summary_df = pd.concat(model_series_list, axis=1).T

# %%
summary_df['mean_auc_val'].astype(float).idxmax()
# Out:
# 91

# %%
def get_max(model_df):
    idxmax = model_df['mean_auc_val'].astype(float).idxmax()
    return model_df.loc[idxmax].drop(index=['dataset', 'model_name', 'params']).astype(float)


summary_df.groupby(['dataset', 'model_name'], group_keys=False).apply(
    get_max).style.background_gradient(axis=0).format(lambda x: f'{x:.3f}')
# Out:
# <style type="text/css">
# #T_dadbd_row0_col0 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_dadbd_row0_col1 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_dadbd_row0_col2 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_dadbd_row0_col3 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_dadbd_row0_col4 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_dadbd_row0_col5 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_dadbd_row1_col0 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_dadbd_row1_col1 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_dadbd_row1_col2 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_dadbd_row1_col3, #T_dadbd_row2_col3 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_dadbd_row1_col4 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_dadbd_row1_col5 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_dadbd_row2_col0 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_dadbd_row2_col1 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_dadbd_row2_col2 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_dadbd_row2_col4, #T_dadbd_row17_col0 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_dadbd_row2_col5 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_dadbd_row3_col0 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_dadbd_row3_col1, #T_dadbd_row4_col1, #T_dadbd_row5_col3, #T_dadbd_row5_col5, #T_dadbd_row12_col2, #T_dadbd_row13_col0, #T_dadbd_row13_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_dadbd_row3_col2 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_dadbd_row3_col3 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_dadbd_row3_col4 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_dadbd_row3_col5, #T_dadbd_row8_col3, #T_dadbd_row9_col5 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_dadbd_row4_col0, #T_dadbd_row12_col1, #T_dadbd_row12_col3, #T_dadbd_row12_col5, #T_dadbd_row16_col0, #T_dadbd_row16_col2, #T_dadbd_row16_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_dadbd_row4_col2 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_dadbd_row4_col3 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_dadbd_row4_col4 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_dadbd_row4_col5 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_dadbd_row5_col0 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_dadbd_row5_col1, #T_dadbd_row7_col3 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_dadbd_row5_col2 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_dadbd_row5_col4 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_dadbd_row6_col0 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_dadbd_row6_col1 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_dadbd_row6_col2 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_dadbd_row6_col3 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_dadbd_row6_col4 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_dadbd_row6_col5 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_dadbd_row7_col0 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_dadbd_row7_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_dadbd_row7_col2, #T_dadbd_row17_col3 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_dadbd_row7_col4 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_dadbd_row7_col5, #T_dadbd_row16_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_dadbd_row8_col0 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_dadbd_row8_col1, #T_dadbd_row8_col5, #T_dadbd_row11_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_dadbd_row8_col2, #T_dadbd_row10_col2 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_dadbd_row8_col4 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_dadbd_row9_col0 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_dadbd_row9_col1, #T_dadbd_row10_col3 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_dadbd_row9_col2 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_dadbd_row9_col3, #T_dadbd_row10_col5 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_dadbd_row9_col4, #T_dadbd_row15_col3 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_dadbd_row10_col0 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_dadbd_row10_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_dadbd_row10_col4 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_dadbd_row11_col0 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_dadbd_row11_col1 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_dadbd_row11_col2 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_dadbd_row11_col4 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_dadbd_row11_col5, #T_dadbd_row12_col0, #T_dadbd_row12_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_dadbd_row13_col1, #T_dadbd_row13_col3, #T_dadbd_row13_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_dadbd_row13_col2 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_dadbd_row14_col0 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_dadbd_row14_col1 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_dadbd_row14_col2 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_dadbd_row14_col3 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_dadbd_row14_col4 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_dadbd_row14_col5 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_dadbd_row15_col0 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_dadbd_row15_col1 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_dadbd_row15_col2 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_dadbd_row15_col4 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_dadbd_row15_col5 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_dadbd_row16_col3 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_dadbd_row16_col5 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_dadbd_row17_col1 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_dadbd_row17_col2 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_dadbd_row17_col4 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_dadbd_row17_col5 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# </style>
# <table id="T_dadbd">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dadbd_level0_col0" class="col_heading level0 col0" >mean_auc_train</th>
#       <th id="T_dadbd_level0_col1" class="col_heading level0 col1" >std_auc_train</th>
#       <th id="T_dadbd_level0_col2" class="col_heading level0 col2" >mean_auc_val</th>
#       <th id="T_dadbd_level0_col3" class="col_heading level0 col3" >std_auc_val</th>
#       <th id="T_dadbd_level0_col4" class="col_heading level0 col4" >mean_auc_test</th>
#       <th id="T_dadbd_level0_col5" class="col_heading level0 col5" >std_auc_test</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="index_name level1" >model_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dadbd_level0_row0" class="row_heading level0 row0" rowspan="6">cora</th>
#       <th id="T_dadbd_level1_row0" class="row_heading level1 row0" >$\Omega_{p}GraphSage$</th>
#       <td id="T_dadbd_row0_col0" class="data row0 col0" >0.713</td>
#       <td id="T_dadbd_row0_col1" class="data row0 col1" >0.008</td>
#       <td id="T_dadbd_row0_col2" class="data row0 col2" >0.791</td>
#       <td id="T_dadbd_row0_col3" class="data row0 col3" >0.005</td>
#       <td id="T_dadbd_row0_col4" class="data row0 col4" >0.730</td>
#       <td id="T_dadbd_row0_col5" class="data row0 col5" >0.005</td>
#     </tr>
#     <tr>
#       <th id="T_dadbd_level1_row1" class="row_heading level1 row1" >$\Omega_{p}Node2Vec$</th>
#       <td id="T_dadbd_row1_col0" class="data row1
