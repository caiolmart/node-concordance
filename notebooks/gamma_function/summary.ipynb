# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

while 'notebooks' in os.getcwd():
    os.chdir('..')

import pandas as pd
import numpy as np
from sklearn.model_selection import ParameterGrid

from src.train.structural_omega.graph_sage import StructuralOmegaGraphSageCosSim
from src.train.structural_omega.gcn import StructuralOmegaGCNCosSim
from src.train.structural_omega.mlp import StructuralOmegaMLP
from src.train.structural_omega.gat import StructuralOmegaGATCosSim
from src.train.positional_omega.graph_sage import PositionalOmegaGraphSageCosSim
from src.train.positional_omega.node2vec import PositionalOmegaNode2Vec

# %%
model_parameters = [
    {
        'model': StructuralOmegaGraphSageCosSim,
        'parameter_range':{
            'n_layers_graph_sage': list(range(1, 4))
        }
    },
    {
        'model': StructuralOmegaGCNCosSim,
        'parameter_range':{
            'n_layers_gcn': list(range(1, 4))
        }
    },
    {
        'model': StructuralOmegaMLP,
        'parameter_range':{
            'n_layers': list(range(1, 6))
        }
    },
    {
        'model': StructuralOmegaGATCosSim,
        'parameter_range':{
            'n_layers_gat': list(range(1, 4))
        }
    },
    {
        'model': StructuralOmegaMLP,
        'parameter_range':{
            'n_layers': list(range(1, 4))
        }
    },
    {
        'model': PositionalOmegaGraphSageCosSim,
        'parameter_range':{
            'n_layers': list(range(1, 4))
        }
    },
    {
        'model': PositionalOmegaNode2Vec,
        'parameter_range':{
            'p': np.logspace(-1, 1, 5).round(2).tolist(),
            'q': np.logspace(-1, 1, 5).round(2).tolist()
        }
    }
]

# %%
model = PositionalOmegaGraphSageCosSim

# %%
model.__name__
# Out:
# 'PositionalOmegaGraphSageCosSim'

# %%
model_series_list = []
for dataset in ['ogbn-arxiv', 'cora']:
    for model_dict in model_parameters:
        model = model_dict['model']
        model_name = model.__name__
        for params in ParameterGrid(model_dict['parameter_range']):
            metrics = model.read_metrics(dataset, **params)
            aucs_list = []
            for run in metrics['run'].unique():
                sub_df = metrics.query(f'run == {run}')
                idxmax = sub_df['auc_val'].idxmax()
                aucs = sub_df.loc[idxmax, ['auc_train', 'auc_val', 'auc_test']]
                aucs_list.append(aucs.rename(run))

            aucs_df = pd.concat(aucs_list, axis=1).rename_axis(columns='run').T
            aucs_mean = aucs_df.mean()
            aucs_std = aucs_df.std()

            model_series_list.append(pd.Series({
                'dataset': dataset,
                'model_name': model_name,
                'params': params,
                'mean_auc_train': aucs_mean['auc_train'],
                'std_auc_train': aucs_std['auc_train'],
                'mean_auc_val': aucs_mean['auc_val'],
                'std_auc_val': aucs_std['auc_val'],
                'mean_auc_test': aucs_mean['auc_test'],
                'std_auc_test': aucs_std['auc_test'],
            }))

summary_df = pd.concat(model_series_list, axis=1).T

# %%
summary_df
# Out:
#        dataset                      model_name                      params  \
# 0   ogbn-arxiv  StructuralOmegaGraphSageCosSim  {'n_layers_graph_sage': 1}
# 1   ogbn-arxiv  StructuralOmegaGraphSageCosSim  {'n_layers_graph_sage': 2}
# 2   ogbn-arxiv  StructuralOmegaGraphSageCosSim  {'n_layers_graph_sage': 3}
# 3   ogbn-arxiv        StructuralOmegaGCNCosSim         {'n_layers_gcn': 1}
# 4   ogbn-arxiv        StructuralOmegaGCNCosSim         {'n_layers_gcn': 2}
# ..         ...                             ...                         ...
# 85        cora         PositionalOmegaNode2Vec       {'p': 10.0, 'q': 0.1}
# 86        cora         PositionalOmegaNode2Vec      {'p': 10.0, 'q': 0.32}
# 87        cora         PositionalOmegaNode2Vec       {'p': 10.0, 'q': 1.0}
# 88        cora         PositionalOmegaNode2Vec      {'p': 10.0, 'q': 3.16}
# 89        cora         PositionalOmegaNode2Vec      {'p': 10.0, 'q': 10.0}
#
#    mean_auc_train std_auc_train mean_auc_val std_auc_val mean_auc_test  \
# 0        0.833655      0.000578     0.803573    0.000166      0.774845
# 1        0.876891      0.005401      0.82857    0.001862       0.79265
# 2        0.890174      0.002311     0.848632    0.001677      0.817013
# 3        0.785775       0.00121     0.781448    0.000395      0.760862
# 4        0.853997      0.002835     0.836976    0.001716       0.81015
# ..            ...           ...          ...         ...           ...
# 85       0.553903      0.039018     0.565294    0.012467      0.569602
# 86       0.561533      0.027831     0.567862    0.036673      0.556509
# 87       0.557592       0.02223     0.562054    0.023377      0.555846
# 88       0.545672      0.037902     0.581606    0.030513      0.564161
# 89       0.550308       0.01665     0.564118    0.027808      0.554202
#
#    std_auc_test
# 0      0.000308
# 1      0.002747
# 2      0.001488
# 3      0.000787
# 4      0.002574
# ..          ...
# 85     0.013505
# 86     0.021694
# 87     0.016991
# 88     0.004561
# 89     0.006086
#
# [90 rows x 9 columns]

# %%
summary_df['mean_auc_val'].astype(float).idxmax()
# Out:
# 48

# %%
def get_max(model_df):
    idxmax = model_df['mean_auc_val'].astype(float).idxmax()
    return model_df.loc[idxmax].drop(index=['dataset', 'model_name', 'params']).astype(float)


summary_df.groupby(['dataset', 'model_name'], group_keys=False).apply(
    get_max).style.background_gradient(axis=0).format(lambda x: f'{x:.3f}')
# Out:
# <style type="text/css">
# #T_e3086_row0_col0 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_e3086_row0_col1 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_e3086_row0_col2 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_e3086_row0_col3 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_e3086_row0_col4 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_e3086_row0_col5 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_e3086_row1_col0, #T_e3086_row1_col2, #T_e3086_row1_col4, #T_e3086_row3_col1, #T_e3086_row4_col1, #T_e3086_row5_col3, #T_e3086_row5_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e3086_row1_col1, #T_e3086_row1_col3, #T_e3086_row2_col3, #T_e3086_row2_col5, #T_e3086_row3_col2, #T_e3086_row4_col0, #T_e3086_row9_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e3086_row1_col5 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_e3086_row2_col0 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_e3086_row2_col1, #T_e3086_row10_col2 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_e3086_row2_col2 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_e3086_row2_col4 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_e3086_row3_col0, #T_e3086_row8_col4 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_e3086_row3_col3, #T_e3086_row9_col1 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_e3086_row3_col4 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_e3086_row3_col5 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_e3086_row4_col2 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_e3086_row4_col3, #T_e3086_row6_col2, #T_e3086_row6_col5 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_e3086_row4_col4 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_e3086_row4_col5 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_e3086_row5_col0 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_e3086_row5_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_e3086_row5_col2 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_e3086_row5_col4 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_e3086_row6_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_e3086_row6_col1 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_e3086_row6_col3 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_e3086_row6_col4, #T_e3086_row11_col1, #T_e3086_row11_col2 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_e3086_row7_col0, #T_e3086_row7_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_e3086_row7_col1, #T_e3086_row7_col5, #T_e3086_row9_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_e3086_row7_col3 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_e3086_row7_col4 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_e3086_row8_col0 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_e3086_row8_col1, #T_e3086_row8_col5 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_e3086_row8_col2 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_e3086_row8_col3, #T_e3086_row11_col5 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_e3086_row9_col0 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_e3086_row9_col2 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_e3086_row9_col5 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_e3086_row10_col0 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_e3086_row10_col1 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_e3086_row10_col3, #T_e3086_row11_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_e3086_row10_col4 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_e3086_row10_col5 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_e3086_row11_col0 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_e3086_row11_col4 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# </style>
# <table id="T_e3086">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3086_level0_col0" class="col_heading level0 col0" >mean_auc_train</th>
#       <th id="T_e3086_level0_col1" class="col_heading level0 col1" >std_auc_train</th>
#       <th id="T_e3086_level0_col2" class="col_heading level0 col2" >mean_auc_val</th>
#       <th id="T_e3086_level0_col3" class="col_heading level0 col3" >std_auc_val</th>
#       <th id="T_e3086_level0_col4" class="col_heading level0 col4" >mean_auc_test</th>
#       <th id="T_e3086_level0_col5" class="col_heading level0 col5" >std_auc_test</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="index_name level1" >model_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3086_level0_row0" class="row_heading level0 row0" rowspan="6">cora</th>
#       <th id="T_e3086_level1_row0" class="row_heading level1 row0" >PositionalOmegaGraphSageCosSim</th>
#       <td id="T_e3086_row0_col0" class="data row0 col0" >0.713</td>
#       <td id="T_e3086_row0_col1" class="data row0 col1" >0.008</td>
#       <td id="T_e3086_row0_col2" class="data row0 col2" >0.791</td>
#       <td id="T_e3086_row0_col3" class="data row0 col3" >0.005</td>
#       <td id="T_e3086_row0_col4" class="data row0 col4" >0.730</td>
#       <td id="T_e3086_row0_col5" class="data row0 col5" >0.005</td>
#     </tr>
#     <tr>
#       <th id="T_e3086_level1_row1" class="row_heading level1 row1" >PositionalOmegaNode2Vec</th>
#       <td id="T_e3086_row1_col0" class="data row1 col0" >0.617</td>
#       <td id="T_e3086_row1_col1" class="data row1 col1" >0.011</td>
#       <td id="T_e3086_row1_col2" class="data row1 col2" >0.635</td>
#       <td id="T_e3086_row1_col3" class="data row1 col3" >0.012</td>
#       <td id="T_e3086_row1_col4" class="data row1 col4" >0.596</td>
#       <td id="T_e3086_row1_col5" class="data row1 col5" >0.011</td>
#     </tr>
#     <tr>
#       <th id="T_e3086_level1_row2" class="row_heading level1 row2" >StructuralOmegaGATCosSim</th>
#       <td id="T_e3086_row2_col0" class="data row2 col0" >0.945</td>
#       <td id="T_e3086_row2_col1" class="data row2 col1" >0.009</td>
#       <td id="T_e3086_row2_col2" class="data row2 col2" >0.853</td>
#       <td id="T_e3086_row2_col3" class="data row2 col3" >0.012</td>
#       <td id="T_e3086_row2_col4" class="data row2 col4" >0.789</td>
#       <td id="T_e3086_row2_col5" class="data row2 col5" >0.015</td>
#     </tr>
#     <tr>
#       <th id="T_e3086_level1_row3" class="row_heading level1 row3" >StructuralOmegaGCNCosSim</th>
#       <td id="T_e3086_row3_col0" class="data row3 col0" >0.995</td>
#       <td id="T_e3086_row3_col1" class="data row3 col1" >0.000</td>
#       <td id="T_e3086_row3_col2" class="data row3 col2" >0.878</td>
#       <td id="T_e3086_row3_col3" class="data row3 col3" >0.002</td>
#       <td id="T_e3086_row3_col4" class="data row3 col4" >0.819</td>
#       <td id="T_e3086_row3_col5" class="data row3 col5" >0.002</td>
#     </tr>
#     <tr>
#       <th id="T_e3086_level1_row4" class="row_heading level1 row4" >StructuralOmegaGraphSageCosSim</th>
#       <td id="T_e3086_row4_col0" class="data row4 col0" >1.000</td>
#       <td id="T_e3086_row4_col1" class="data row4 col1" >0.000</td>
#       <td id="T_e3086_row4_col2" class="data row4 col2" >0.871</td>
#       <td id="T_e3086_row4_col3" class="data row4 col3" >0.003</td>
#       <td id="T_e3086_row4_col4" class="data row4 col4" >0.822</td>
#       <td id="T_e3086_row4_col5" class="data row4 col5" >0.002</td>
#     </tr>
#     <tr>
#       <th id="T_e3086_level1_row5" class="row_heading level1 row5" >StructuralOmegaMLP</th>
#       <td id="T_e3086_row5_col0" class="data row5 col0" >0.926</td>
#       <td id="T_e3086_row5_col1" class="data row5 col1" >0.002</td>
#       <td id="T_e3086_row5_col2" class="data row5 col2" >0.711</td>
#       <td id="T_e3086_row5_col3" class="data row5 col3" >0.001</td>
#       <td id="T_e3086_
