# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os

while 'notebooks' in os.getcwd():
    os.chdir('..')

import torch
import torch_geometric.transforms as T
from sklearn.metrics import roc_auc_score
import logging
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.offline as pyo
import numpy as np
import pandas as pd

from src.torch_geo_models import DotMLPRelu
from src.data.gamma.structural_pubmed import load_dataset, get_train_val_test_edges, prepare_adjencency, get_edge_index_from_adjencency
from src.train.structural_omega.mlp import StructuralOmegaMLP

# %%
logging.basicConfig(
    format='%(asctime)s - %(levelname)s : %(message)s',
    level=logging.INFO,
    datefmt='%Y-%m-%d %H:%M:%S',
    filename='logs/omega_function/pubmed/02-1-structural_mlp_gamma_function.log'
)

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = f'cuda:0' if torch.cuda.is_available() else 'cpu'
device = torch.device(device)
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ## Data Loading

# %%
dataset = load_dataset()

# %%
dataset[0].edge_index
# Out:
# tensor([[    0,     0,     0,  ..., 19714, 19715, 19716],
#         [ 1378,  1544,  6092,  ..., 12278,  4284, 16030]])

# %%
data, edges_train, edges_val, edges_test = get_train_val_test_edges(dataset, device=device)

# %%
data = prepare_adjencency(data)

# %% [markdown]
# ## Training

# %%
data.x.shape
# Out:
# torch.Size([19717, 500])

# %%
data.x
# Out:
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.1046, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0000, 0.0194, 0.0080,  ..., 0.0000, 0.0000, 0.0000],
#         [0.1078, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0266, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')

# %%
data.y
# Out:
# tensor([1, 1, 0,  ..., 2, 0, 2], device='cuda:0')

# %%
for run in range(10):
    for n_layers in range(1, 6):
        omega = StructuralOmegaMLP(
            device,
            dataset='pubmed',
            in_channels=data.x.shape[1],
            n_layers=n_layers,
            run=run
        )
        torch.cuda.empty_cache()
        omega.train(edges_train,
                    edges_val,
                    edges_test,
                    data.x,
                    data.y.reshape(-1, 1))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/caiolmartinelli/usr/dev/mestrado/experiments/arxiv-paperclassification/notebooks/gamma_function/pubmed/02-1-structural_mlp_omega_function.ipynb Cell 15 in 1
#       <a href='vscode-notebook-cell:/home/caiolmartinelli/usr/dev/mestrado/experiments/arxiv-paperclassification/notebooks/gamma_function/pubmed/02-1-structural_mlp_omega_function.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> omega = StructuralOmegaMLP(
#       <a href='vscode-notebook-cell:/home/caiolmartinelli/usr/dev/mestrado/experiments/arxiv-paperclassification/notebooks/gamma_function/pubmed/02-1-structural_mlp_omega_function.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a>     device,
#       <a href='vscode-notebook-cell:/home/caiolmartinelli/usr/dev/mestrado/experiments/arxiv-paperclassification/notebooks/gamma_function/pubmed/02-1-structural_mlp_omega_function.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a>     dataset='pubmed',
#    (...)
#       <a href='vscode-notebook-cell:/home/caiolmartinelli/usr/dev/mestrado/experiments/arxiv-paperclassification/notebooks/gamma_function/pubmed/02-1-structural_mlp_omega_function.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a>     run=run
#       <a href='vscode-notebook-cell:/home/caiolmartinelli/usr/dev/mestrado/experiments/arxiv-paperclassification/notebooks/gamma_function/pubmed/02-1-structural_mlp_omega_function.ipynb#X20sZmlsZQ%3D%3D?line=8'>9</a> )
#      <a href='vscode-notebook-cell:/home/caiolmartinelli/usr/dev/mestrado/experiments/arxiv-paperclassification/notebooks/gamma_function/pubmed/02-1-structural_mlp_omega_function.ipynb#X20sZmlsZQ%3D%3D?line=9'>10</a> torch.cuda.empty_cache()
# ---> <a href='vscode-notebook-cell:/home/caiolmartinelli/usr/dev/mestrado/experiments/arxiv-paperclassification/notebooks/gamma_function/pubmed/02-1-structural_mlp_omega_function.ipynb#X20sZmlsZQ%3D%3D?line=10'>11</a> omega.train(edges_train,
#      <a href='vscode-notebook-cell:/home/caiolmartinelli/usr/dev/mestrado/experiments/arxiv-paperclassification/notebooks/gamma_function/pubmed/02-1-structural_mlp_omega_function.ipynb#X20sZmlsZQ%3D%3D?line=11'>12</a>             edges_val,
#      <a href='vscode-notebook-cell:/home/caiolmartinelli/usr/dev/mestrado/experiments/arxiv-paperclassification/notebooks/gamma_function/pubmed/02-1-structural_mlp_omega_function.ipynb#X20sZmlsZQ%3D%3D?line=12'>13</a>             edges_test,
#      <a href='vscode-notebook-cell:/home/caiolmartinelli/usr/dev/mestrado/experiments/arxiv-paperclassification/notebooks/gamma_function/pubmed/02-1-structural_mlp_omega_function.ipynb#X20sZmlsZQ%3D%3D?line=13'>14</a>             data.x,
#      <a href='vscode-notebook-cell:/home/caiolmartinelli/usr/dev/mestrado/experiments/arxiv-paperclassification/notebooks/gamma_function/pubmed/02-1-structural_mlp_omega_function.ipynb#X20sZmlsZQ%3D%3D?line=14'>15</a>             data.y.reshape(-1, 1))
#
# File ~/usr/dev/mestrado/experiments/arxiv-paperclassification/src/train/structural_omega/mlp.py:204, in StructuralOmegaMLP.train(self, edges_train, edges_val, edges_test, x, y)
#     194 self.save_metrics(
#     195     0,
#     196     loss_train,
#    (...)
#     200     auc_val,
#     201     auc_test)
#     203 for epoch in range(1, 1 + self.epochs):
# --> 204     self.train_epoch(edges_train, self.batch_size, x, y)
#     206     if epoch % self.eval_steps == 0:
#     207         loss_train, loss_val, loss_test, auc_train, auc_val, auc_test = self.eval(
#     208             edges_train,
#     209             edges_val,
#     210             edges_test,
#     211             x,
#     212             y)
#
# File ~/usr/dev/mestrado/experiments/arxiv-paperclassification/src/train/structural_omega/mlp.py:78, in StructuralOmegaMLP.train_epoch(self, edges_train, batch_size, x, y)
#      74 theta_perm = self.is_same_class(perm, y).to(torch.float32)
#      76 predicted = self.predictor(x[perm[0]], x[perm[1]])
# ---> 78 perm_loss = self.loss(predicted, theta_perm)
#      80 perm_loss.backward()
#      82 torch.nn.utils.clip_grad_norm_(self.predictor.parameters(), 1.0)
#
# File ~/.cache/pypoetry/virtualenvs/arxiv-paperclassification-f16XUvnj-py3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.cache/pypoetry/virtualenvs/arxiv-paperclassification-f16XUvnj-py3.10/lib/python3.10/site-packages/torch/nn/modules/loss.py:619, in BCELoss.forward(self, input, target)
#     618 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 619     return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
#
# File ~/.cache/pypoetry/virtualenvs/arxiv-paperclassification-f16XUvnj-py3.10/lib/python3.10/site-packages/torch/nn/functional.py:3095, in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    3092     new_size = _infer_size(target.size(), weight.size())
#    3093     weight = weight.expand(new_size)
# -> 3095 return torch._C._nn.binary_cross_entropy(input, target, weight, reduction_enum)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Results

# %% [markdown]
# ### For a Layer Number

# %%
n_layers = 3

# %%
metrics = StructuralOmegaMLP.read_metrics(dataset='pubmed', n_layers=n_layers)
print(metrics.shape)
metrics.head()
# Out:
# (714, 8)
#    run  epoch  loss_train  loss_val  loss_test  auc_train   auc_val  auc_test
# 0    0      0    0.689262  0.688982   0.689089   0.487635  0.459498  0.484432
# 1    0    100    0.462735  0.431742   0.445564   0.713352  0.718177  0.709511
# 2    0    200    0.429990  0.423415   0.431724   0.760768  0.740211  0.732087
# 3    0    300    0.412152  0.426205   0.430263   0.787655  0.742691  0.740144
# 4    0    400    0.393425  0.424585   0.430372   0.811398  0.746398  0.745299

# %% [markdown]
# ### Sumarize metrics per epoch

# %%
metrics_cols = metrics.columns[2:]
metrics_cols
# Out:
# Index(['loss_train', 'loss_val', 'loss_test', 'auc_train', 'auc_val',
#        'auc_test'],
#       dtype='object')

# %%
metrics['loss_train'] = metrics\
    .replace('None', np.nan)\
    ['loss_train']\
    .astype(float)

# %%
epoch_metrics = metrics\
    .fillna(-1)\
    .groupby('epoch')\
    [metrics_cols]\
    .agg(['mean', 'std'])
epoch_metrics.columns = [f'{x[0]}_{x[1]}' for x in epoch_metrics.columns]
epoch_metrics.head()
# Out:
#        loss_train_mean  loss_train_std  loss_val_mean  loss_val_std  \
# epoch
# 0             0.693493        0.012202       0.693504      0.013112
# 100           0.462247        0.003288       0.431397      0.002613
# 200           0.430779        0.002800       0.423644      0.001118
# 300           0.413983        0.005895       0.426434      0.001855
# 400           0.396905        0.009242       0.426448      0.003012
#
#        loss_test_mean  loss_test_std  auc_train_mean  auc_train_std  \
# epoch
# 0            0.693500       0.012752        0.506813       0.029348
# 100          0.444997       0.002636        0.713751       0.003226
# 200          0.432187       0.000822        0.760064       0.004349
# 300          0.431885       0.001961        0.785566       0.007661
# 400          0.432600       0.002101        0.808005       0.010777
#
#        auc_val_mean  auc_val_std  auc_test_mean  auc_test_std
# epoch
# 0          0.503811     0.044963       0.504428      0.034089
# 100        0.718512     0.003369       0.709667      0.002243
# 200        0.741324     0.001332       0.731810      0.001160
# 300        0.742651     0.002441       0.738462      0.003053
# 400        0.743676     0.003470       0.742596      0.003248

# %%
epoch_metrics.sort_values('auc_val_mean', ascending=False).head()
# Out:
#        loss_train_mean  loss_train_std  loss_val_mean  loss_val_std  \
# epoch
# 700           0.350401        0.014592       0.442237      0.020871
# 600           0.366463        0.013246       0.432698      0.014039
# 800           0.336681        0.019067       0.464453      0.023621
# 500           0.380099        0.012008       0.426330      0.004045
# 900           0.322551        0.021409       0.473041      0.021605
#
#        loss_test_mean  loss_test_std  auc_train_mean  auc_train_std  \
# epoch
# 700          0.442300       0.005119        0.857365       0.013299
# 600          0.438423       0.003579        0.842852       0.013122
# 800          0.447267       0.005509        0.870136       0.014883
# 500          0.434043       0.002354        0.827500       0.011966
# 900          0.454400       0.009607        0.880383       0.016158
#
#        auc_val_mean  auc_val_std  auc_test_mean  auc_test_std
# epoch
# 700        0.746475     0.005420       0.744924      0.003631
# 600        0.745929     0.005038       0.744811      0.003551
# 800        0.745507     0.006461       0.743283      0.005140
# 500        0.745397     0.004593       0.744799      0.003607
# 900        0.744663     0.005404       0.742097      0.004865

# %%
plt.rcParams['font.size'] = '14'
fig, ax1 = plt.subplots(1, 1, figsize=(16, 10))

ax1.set_title(f'Structural MLP Baseline Epoch Metrics - {n_layers} Layers')

ax1.errorbar(
    epoch_metrics.index[1:],
    epoch_metrics['loss_train_mean'][1:],
    yerr=epoch_metrics['loss_train_std'][1:],
    ls='-',
    label='Train')

ax1.errorbar(
    epoch_metrics.index,
    epoch_metrics['loss_val_mean'],
    yerr=epoch_metrics['loss_val_std'],
    ls='-',
    label='Validation')

ax1.errorbar(
    epoch_metrics.index,
    epoch_metrics['loss_test_mean'],
    yerr=epoch_metrics['loss_test_std'],
    ls='-',
    label='Test')

# ax1.plot(
#     epoch_metrics.index[1:],
#     epoch_metrics['loss_train_mean'][1:],
#     # yerr=epoch_metrics['loss_train_std'][1:],
#     ls='-',
#     label='Train')

# ax1.plot(
#     epoch_metrics.index,
#     epoch_metrics['loss_val_mean'],
#     # yerr=epoch_metrics['loss_val_std'],
#     ls='-',
#     label='Validation')

# ax1.plot(
#     epoch_metrics.index,
#     epoch_metrics['loss_test_mean'],
#     # yerr=epoch_metrics['loss_test_std'],
#     ls='-',
#     label='Test')

ax1.legend(loc='center right', title='Loss', bbox_to_anchor=[0.85, 0.5])
ax1.set_ylabel('Loss')
ax1.set_xlabel('Epoch')

ax2 = ax1.twinx()

ax2.errorbar(
    epoch_metrics.index[1:],
    epoch_metrics['auc_train_mean'][1:],
    yerr=epoch_metrics['auc_train_std'][1:],
    ls=':',
    label='Train')

ax2.errorbar(
    epoch_metrics.index,
    epoch_metrics['auc_val_mean'],
    yerr=epoch_metrics['auc_val_std'],
    ls=':',
    label='Validation')

ax2.errorbar(
    epoch_metrics.index,
    epoch_metrics['auc_test_mean'],
    yerr=epoch_metrics['auc_test_std'],
    ls=':',
    label='Test')

# ax2.plot(
#     epoch_metrics.index[1:],
#     epoch_metrics['auc_train_mean'][1:],
#     # yerr=epoch_metrics['auc_train_std'][1:],
#     ls=':',
#     label='Train')

# ax2.plot(
#     epoch_metrics.index,
#     epoch_metrics['auc_val_mean'],
#     # yerr=epoch_metrics['auc_val_std'],
#     ls=':',
#     label='Validation')

# ax2.plot(
#     epoch_metrics.index,
#     epoch_metrics['auc_test_mean'],
#     # yerr=epoch_metrics['auc_test_std'],
#     ls=':',
#     label='Test')

ax2.legend(loc='center right', title='ROC-AUC', bbox_to_anchor=[1, 0.5])
ax2.set_ylabel('ROC-AUC')

plt.savefig(f'reports/images/pubmed/structural_omega_dotmlp_training_metrics_{n_layers}layers.pdf')
# Out:
# /tmp/ipykernel_390047/483979402.py:8: FutureWarning:
#
# The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#
# /tmp/ipykernel_390047/483979402.py:9: FutureWarning:
#
# The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#
# /tmp/ipykernel_390047/483979402.py:56: FutureWarning:
#
# The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#
# /tmp/ipykernel_390047/483979402.py:57: FutureWarning:
#
# The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.

# %% [markdown]
# ### Comparing Validation Performance for All Layer numbers

# %%
n_layers_list = range(1, 6)

# %%
mean_auc_val_dict = {}
mean_loss_val_dict = {}
std_auc_val_dict = {}
std_loss_val_dict = {}
for n_layers in n_layers_list:
    metrics = StructuralOmegaMLP.read_metrics(dataset='pubmed', n_layers=n_layers)
    mean_df = metrics.groupby(['epoch'])[['auc_val', 'loss_val']].mean()
    
    auc_val = mean_df['auc_val']
    loss_val = mean_df['loss_val']
    mean_auc_val_dict[n_layers] = auc_val
    mean_loss_val_dict[n_layers] = loss_val

    std_df = metrics.groupby(['epoch'])[['auc_val', 'loss_val']].std()

    auc_val = std_df['auc_val']
    loss_val = std_df['loss_val']
    std_auc_val_dict[n_layers] = auc_val
    std_loss_val_dict[n_layers] = loss_val

# %%
plt.rcParams['font.size'] = '14'
fig, ax1 = plt.subplots(1, 1, figsize=(16, 10))

ax1.set_title('Validation Epochs ROC-AUC - Structural MLP Baseline')

for n_layers in mean_auc_val_dict:
    ax1.errorbar(
        mean_auc_val_dict[n_layers].index,
        mean_auc_val_dict[n_layers],
        yerr=std_auc_val_dict[n_layers],
        ls='-',
        label=f'{n_layers}-MLP')

ax1.set_xlim(-50, 2000)

ax1.legend()

ax1.set_xlabel('Epoch')
ax1.set_ylabel('ROC-AUC')

plt.savefig(f'reports/images/pubmed/structural_omega_dotmlp_training_metrics_multilayer_validation.pdf')
